# %% [markdown]
# # Exploring the Data
# ## Part 1 - Creating Columns to Help Summarize Data

# %%
import numpy as np 
import pandas as pd 
import re
import nltk
import spacy
from collections import Counter
import re
# nltk.download('stopwords')
# nltk.download('punkt')
import matplotlib.pyplot as plt
import geopandas as gpd
import descartes
# %matplotlib inline

# %%
# Load Data of interest
load_data = pd.read_csv('info_672.csv')
load_data

# If you need to append extra rows to a data frame with the same columns, use .append
# combined = firsthalf.append(secondhalf, ignore_index = True)
# combined
# Out:
#                                              job_title  \
# 0                                Sustainability Intern
# 1              Environmental Sustainability Internship
# 2                               SUSTAINABILITY ANALYST
# 3                 Sustainability Innovation Consultant
# 4                             Sustainability Associate
# ..                                                 ...
# 668  Staff Sustainability Strategy & Disclosure Con...
# 669                     ESG and Sustainability Manager
# 670                            Manager, Sustainability
# 671  Associate Consultant, Sustainability & Social ...
# 672  Environmental Stewardship & Sustainability Ana...
#
#                                         location           job_key  \
# 0                                         Remote  f5438de8a8e1629a
# 1                                 Providence, RI  7075a3a7b5571059
# 2                                     Austin, TX  2171570f88a3a65d
# 3                                         Remote  e862369e52ce2651
# 4                                 Louisville, KY  00a0e465fe8342c8
# ..                                           ...               ...
# 668         Washington, DC 20036 (Downtown area)  037f3323b9192c81
# 669                                   Denver, CO  cf4d4f9e0009297a
# 670                                    Omaha, NE  cc7e05bf63d6cb1d
# 671  New York, NY 10010 (Flatiron District area)  cf188c93641c2e26
# 672                               Queen Anne, WA  2fc2a329bf2d43fc
#
#                                       job_descriptions  \
# 0    About Imperfect\nImperfect Foods was founded i...
# 1    About:  Jellyfish is a newly founded venture t...
# 2    Austin, USA\nLongevity Partners is a boutique ...
# 3    7+ years of experience in consulting, solution...
# 4    Schneider Electric™ creates connected technolo...
# ..                                                 ...
# 668  ERM is seeking a motivated and dynamic Sustain...
# 669  Discover your full potential. At Tetra Tech, w...
# 670  Department FMP-Administration 50000761 Busines...
# 671  APCO Impact is a unique consultancy that takes...
# 672  Job SummaryWe offer competitive salary, great ...
#
#                               company_name                   ceo  founded  \
# 0                          Imperfect Foods           Philip Behn     2015
# 1                                Jellyfish                    -1     2005
# 2                       LONGEVITY PARTNERS                    -1       -1
# 3                Amazon Web Services, Inc.                    -1       -1
# 4                       Schneider Electric  Jean-Pascal Tricoire       -1
# ..                                     ...                   ...      ...
# 668                              ERM Group                    -1     1971
# 669                             Tetra Tech        Dan L. Batrack     1966
# 670  University of Nebraska Medical Center                    -1     1995
# 671                         APCO Worldwide                    -1     1984
# 672              Seattle Housing Authority                    -1     1939
#
#                  size               revenue  \
# 0       1001 to 5,000   less than $1M (USD)
# 1           51 to 200     $5M to $25M (USD)
# 2            11 to 50                    -1
# 3                  -1                    -1
# 4    more than 10,000  more than $10B (USD)
# ..                ...                   ...
# 668     1001 to 5,000  $100M to $500M (USD)
# 669  more than 10,000      $1B to $5B (USD)
# 670   5,001 to 10,000  $100M to $500M (USD)
# 671      501 to 1,000   $25M to $100M (USD)
# 672      501 to 1,000   less than $1M (USD)
#
#                                  industry
# 0                           Manufacturing
# 1              Restaurants & Food Service
# 2                                      -1
# 3                  Information Technology
# 4              Energy, Mining & Utilities
# ..                                    ...
# 668                         HR Consulting
# 669  Architectural & Engineering Services
# 670                             Education
# 671                 Media & Communication
# 672                                    -1
#
# [673 rows x 10 columns]

# %%
# cleaning up the job title
#job_title - Title, get rid of parentheses. Sustainability in title, yes or no?
load_data['job_title_edit'] = load_data['job_title'].apply(lambda x: re.findall("^[^\(]+",x.title())[0])

#Add column identifying if sustainability in title.
load_data['sust_title'] = load_data['job_title'].apply(lambda x: "Yes" if 'sustainability' in x.lower() else "No")

load_data[load_data['sust_title'] == 'Yes']['job_title_edit'] 
#there are 237 job titles with sustainability in them
# Out:
# 0                                  Sustainability Intern
# 1                Environmental Sustainability Internship
# 2                                 Sustainability Analyst
# 3                   Sustainability Innovation Consultant
# 4                               Sustainability Associate
#                              ...
# 668    Staff Sustainability Strategy & Disclosure Con...
# 669                       Esg And Sustainability Manager
# 670                              Manager, Sustainability
# 671    Associate Consultant, Sustainability & Social ...
# 672    Environmental Stewardship & Sustainability Ana...
# Name: job_title_edit, Length: 237, dtype: object

# %%
# cleaning up location - Boil it down to State and "Remote"

#https://gist.github.com/rogerallen/1583593
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}
us_state_abbrev['New York State'] = 'NY'
us_state_abbrev['Washington State'] = 'WA'
us_state_abbrev['United States'] = 'n/a'

# create new column 'location_edit'
# populate with remote, the state ID or n/a if it can't identify state id
load_data['location_edit'] = ["Remote" if (x.lower() == 'remote') else ((re.findall("[A-Z]{2}", x)[0]) if len(re.findall("[A-Z]{2}", x)) != 0 else 'n/a') for x in load_data['location']]

#there are locations that are not a state ID or remote. need to change those to N/A or convert to state
for x in range(len(load_data)):
    if len(load_data.loc[x,'location_edit']) != 2 and load_data.loc[x,'location_edit'] != 'Remote':
        load_data.loc[x,'location_edit'] = us_state_abbrev[load_data.loc[x,'location']]

# %%
load_data['location_edit'].unique()
# Out:
# array(['Remote', 'RI', 'TX', 'KY', 'DC', 'GA', 'NY', 'CA', 'IA', 'WA',
#        'AZ', 'IL', 'NC', 'MA', 'OK', 'VA', 'NJ', 'MI', 'AR', 'OH', 'UT',
#        'FL', 'MD', 'MN', 'MO', 'n/a', 'ND', 'ME', 'CO', 'PA', 'OR', 'SC',
#        'IN', 'GU', 'TN', 'MT', 'ID', 'CT', 'WI', 'NV', 'NM', 'NE', 'AL',
#        'NH', 'SD', 'VT', 'WY', 'DE', 'HI', 'LA'], dtype=object)

# %%
#job_descriptions

#Add column identifying if sustainability in description
load_data['sust_desc'] = load_data['job_descriptions'].apply(lambda x: 'Yes' if 'sustainability' in x.lower() else 'No')

# %%
#company_name (title format)
load_data['company_name'] = load_data['company_name'].apply(lambda x: x.title())

# %%
#size categorize into = very small, small, medium, large, very large company
#-1 - n/a
#less than 10 - very small
#11 to 50 - small
#51 to 200 - medium
#201 to 500 - medium
#501 to 1000 - large
#1001 to 5000 - large
#5001 to 10000 - very large
#more than 10000 - very large

sizemap = {
    '1001 to 5,000': 'large',
    '51 to 200': 'medium',
    '11 to 50': 'small', 
    '-1': 'n/a', 
    'more than 10,000': 'very large',
    '501 to 1,000': 'large', 
    '5,001 to 10,000': 'very large', 
    '201 to 500': 'medium', 
    'less than 10': 'very small'
}

load_data['size'].unique()
load_data['size_category'] = [sizemap[x] for x in load_data['size']]

# %%
#revenue = divide into bigger brackets
#-1 - n/a
#less than $1M
#1M to 100M
#100M to 1B
#1B to 10B
#more than 10B
revmap = {
    'less than $1M (USD)': 'Less than \\$1M', 
    '$5M to $25M (USD)': '\\$1M to \\$100M', 
    '-1' :'n/a',
    'more than $10B (USD)': 'More than \\$10B', 
    '$25M to $100M (USD)': '\\$1M to \\$100M', 
    '$1B to $5B (USD)' : '\\$1B to \\$10B',
    '$5B to $10B (USD)': '\\$1B to \\$10B', 
    '$1M to $5M (USD)':  '\\$1M to \\$100M', 
    '$100M to $500M (USD)': '\\$100M to \\$1B',
    '$500M to $1B (USD)': '\\$100M to \\$1B'
}

load_data['revenue'].unique()
load_data['rev_category'] = [revmap[x] for x in load_data['revenue']]

# %%
load_data
# Out:
#                                              job_title  \
# 0                                Sustainability Intern
# 1              Environmental Sustainability Internship
# 2                               SUSTAINABILITY ANALYST
# 3                 Sustainability Innovation Consultant
# 4                             Sustainability Associate
# ..                                                 ...
# 668  Staff Sustainability Strategy & Disclosure Con...
# 669                     ESG and Sustainability Manager
# 670                            Manager, Sustainability
# 671  Associate Consultant, Sustainability & Social ...
# 672  Environmental Stewardship & Sustainability Ana...
#
#                                         location           job_key  \
# 0                                         Remote  f5438de8a8e1629a
# 1                                 Providence, RI  7075a3a7b5571059
# 2                                     Austin, TX  2171570f88a3a65d
# 3                                         Remote  e862369e52ce2651
# 4                                 Louisville, KY  00a0e465fe8342c8
# ..                                           ...               ...
# 668         Washington, DC 20036 (Downtown area)  037f3323b9192c81
# 669                                   Denver, CO  cf4d4f9e0009297a
# 670                                    Omaha, NE  cc7e05bf63d6cb1d
# 671  New York, NY 10010 (Flatiron District area)  cf188c93641c2e26
# 672                               Queen Anne, WA  2fc2a329bf2d43fc
#
#                                       job_descriptions  \
# 0    About Imperfect\nImperfect Foods was founded i...
# 1    About:  Jellyfish is a newly founded venture t...
# 2    Austin, USA\nLongevity Partners is a boutique ...
# 3    7+ years of experience in consulting, solution...
# 4    Schneider Electric™ creates connected technolo...
# ..                                                 ...
# 668  ERM is seeking a motivated and dynamic Sustain...
# 669  Discover your full potential. At Tetra Tech, w...
# 670  Department FMP-Administration 50000761 Busines...
# 671  APCO Impact is a unique consultancy that takes...
# 672  Job SummaryWe offer competitive salary, great ...
#
#                               company_name                   ceo  founded  \
# 0                          Imperfect Foods           Philip Behn     2015
# 1                                Jellyfish                    -1     2005
# 2                       Longevity Partners                    -1       -1
# 3                Amazon Web Services, Inc.                    -1       -1
# 4                       Schneider Electric  Jean-Pascal Tricoire       -1
# ..                                     ...                   ...      ...
# 668                              Erm Group                    -1     1971
# 669                             Tetra Tech        Dan L. Batrack     1966
# 670  University Of Nebraska Medical Center                    -1     1995
# 671                         Apco Worldwide                    -1     1984
# 672              Seattle Housing Authority                    -1     1939
#
#                  size               revenue  \
# 0       1001 to 5,000   less than $1M (USD)
# 1           51 to 200     $5M to $25M (USD)
# 2            11 to 50                    -1
# 3                  -1                    -1
# 4    more than 10,000  more than $10B (USD)
# ..                ...                   ...
# 668     1001 to 5,000  $100M to $500M (USD)
# 669  more than 10,000      $1B to $5B (USD)
# 670   5,001 to 10,000  $100M to $500M (USD)
# 671      501 to 1,000   $25M to $100M (USD)
# 672      501 to 1,000   less than $1M (USD)
#
#                                  industry  \
# 0                           Manufacturing
# 1              Restaurants & Food Service
# 2                                      -1
# 3                  Information Technology
# 4              Energy, Mining & Utilities
# ..                                    ...
# 668                         HR Consulting
# 669  Architectural & Engineering Services
# 670                             Education
# 671                 Media & Communication
# 672                                    -1
#
#                                         job_title_edit sust_title  \
# 0                                Sustainability Intern        Yes
# 1              Environmental Sustainability Internship        Yes
# 2                               Sustainability Analyst        Yes
# 3                 Sustainability Innovation Consultant        Yes
# 4                             Sustainability Associate        Yes
# ..                                                 ...        ...
# 668  Staff Sustainability Strategy & Disclosure Con...        Yes
# 669                     Esg And Sustainability Manager        Yes
# 670                            Manager, Sustainability        Yes
# 671  Associate Consultant, Sustainability & Social ...        Yes
# 672  Environmental Stewardship & Sustainability Ana...        Yes
#
#     location_edit sust_desc size_category     rev_category
# 0          Remote       Yes         large   Less than \$1M
# 1              RI       Yes        medium   \$1M to \$100M
# 2              TX       Yes         small              n/a
# 3          Remote       Yes           n/a              n/a
# 4              KY       Yes    very large  More than \$10B
# ..            ...       ...           ...              ...
# 668            DC       Yes         large   \$100M to \$1B
# 669            CO       Yes    very large    \$1B to \$10B
# 670            NE       Yes    very large   \$100M to \$1B
# 671            NY       Yes         large   \$1M to \$100M
# 672            WA       Yes         large   Less than \$1M
#
# [673 rows x 16 columns]

# %% [markdown]
# ## Step 2 - Getting to know the data

# %%
load_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 673 entries, 0 to 672
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   job_title         673 non-null    object
#  1   location          673 non-null    object
#  2   job_key           673 non-null    object
#  3   job_descriptions  673 non-null    object
#  4   company_name      673 non-null    object
#  5   ceo               673 non-null    object
#  6   founded           673 non-null    int64
#  7   size              673 non-null    object
#  8   revenue           673 non-null    object
#  9   industry          673 non-null    object
#  10  job_title_edit    673 non-null    object
#  11  sust_title        673 non-null    object
#  12  location_edit     673 non-null    object
#  13  sust_desc         673 non-null    object
#  14  size_category     673 non-null    object
#  15  rev_category      673 non-null    object
# dtypes: int64(1), object(15)
# memory usage: 84.2+ KB

# %%
#How many of the jobs that we pulled have "sustainability" in the title?

load_data['sust_title'].value_counts()
#We got 673 jobs total
#237 have the word 'sustainability' in them
#436 don't
# Out:
# No     436
# Yes    237
# Name: sust_title, dtype: int64

# %%
load_data.sust_title
x = load_data.sust_title.value_counts().index
y = load_data.sust_title.value_counts().values

plt.title('How many of the jobs have "sustainability" in the job title? (n = 673)')
plt.xlabel('Does the job have "sustainability" in the job title?')
plt.ylabel('# of Jobs')

plt.bar(x,y, color = ['lightskyblue','mediumseagreen'])
plt.show()

# %%
#Of the jobs that do have sustainability in their title (n=223), how many also had 'sustainability' in their job descriptions?
load_data[(load_data['sust_title'] == 'Yes') & (load_data['sust_desc'] == 'Yes')] #237 had it in the job description also
x = load_data[(load_data['sust_title'] == 'Yes')].sust_desc.value_counts().index
y = load_data[(load_data['sust_title'] == 'Yes')].sust_desc.value_counts().values

plt.title('How many of the jobs have "sustainability" in the job title AND job description? (n = 237)')
plt.xlabel('Does the job have "sustainability" in the job description?')
plt.ylabel('# of Jobs')

plt.bar(x,y, color = ['mediumseagreen','lightskyblue'])
plt.show()

# %%
#Of the jobs that do NOT have sustainability in their title (n=435), how many had 'sustainability' in their job descriptions?
x = load_data[(load_data['sust_title'] == 'No')].sust_desc.value_counts().index
y = load_data[(load_data['sust_title'] == 'No')].sust_desc.value_counts().values

plt.title('How many of the jobs that do not have "sustainability" in the job title have it in the job description? (n = 436)')
plt.xlabel('Does the job have "sustainability" in the job description?')
plt.ylabel('# of Jobs')

plt.bar(x,y, color = ['mediumseagreen','lightskyblue'])
plt.show()

# %%
#Questionable 44 jobs that do not have 'sustainability' in the title or the job
len(load_data[(load_data['sust_title'] == 'No') & (load_data['sust_desc'] == 'No')] )
# Out:
# 44

# %%
total = len(load_data['sust_title'])

yestitle = len(load_data[(load_data['sust_title'] == 'Yes')]) * 100 / total
# both = len(load_data[(load_data['sust_title'] == 'Yes') & (load_data['sust_desc'] == 'Yes')] ) * 100 / total
onlyt = len(load_data[(load_data['sust_title'] == 'Yes') & (load_data['sust_desc'] == 'No')] ) * 100 / total
onlyd = len(load_data[(load_data['sust_title'] == 'No') & (load_data['sust_desc'] == 'Yes')] ) * 100 / total
neither = len(load_data[(load_data['sust_title'] == 'No') & (load_data['sust_desc'] == 'No')] ) * 100 / total
labels = ["Neither in title nor\ndescription (44)", "No (392)","Yes (237)"]
sizes = [neither,  onlyd,yestitle]
explode = (0.1, 0, 0)
colors = ["lightsteelblue", "cornflowerblue","mediumseagreen"]
plt.rcParams.update({'font.size': 15})
plt.figure(figsize=(7,7))
plt.pie(sizes, labels = labels, colors = colors, explode = explode, autopct = '%1.0f%%', startangle = 90)
# plt.title('subtitle', fontsize= 10)
plt.axis('equal')
plt.suptitle('Did the job have "sustainability" in the title? (n = 673)', fontsize = 20)
plt.show()

# %% [markdown]
# #### Key Takeaways
#  - Total jobs scraped = 673
#  - 237 of them had 'sustainability' in their job title
#  - 436 of them did not have 'sustainability' in the job title, but a majority (392) did have it in the job description
#  - 44 of them that did not have 'sustainability' in the job title or the job description

# %% [markdown]
# ## Step 3 - Exploring the Data

# %%
## what is the difference between the job titles with sustainability and those without?

# difference in frequent job titles?
def frequent_words(theSeries, notWords = [], number = 10):
    '''
    nlp uses en_core_web_sm library
    input:
        theSeries = series you want to analyze frequence words of
        notWords = array of words you don't want to include in frequent word analysis; default = []
        number = # of frequent words wanted; default = 10
    output:
        list of tuples, word and count
    '''
    nlp = spacy.load('en_core_web_sm')
    jobs = ' '.join(theSeries.values)
    doc = nlp(jobs)
    
    # all tokens that arent punctuations and not in notWords
    words = [token.text
             for token in doc
             if not token.is_punct and token.text.lower() not in notWords]

    word_freq = Counter(words)
    print(f'\nNumber of rows included in analysis: {len(theSeries)}')
    return(word_freq.most_common(number))

s = load_data[load_data['sust_title'] == 'Yes']['job_title_edit']
nw = ['for', 'sustainability', 'and', ' ']
n = 10
st_freq = frequent_words(s, nw, n)
st_freq_w = [x[0] for x in st_freq]
print(f'Most frequent words for jobs WITH sustainability in them: \n{st_freq}')

s = load_data[load_data['sust_title'] == 'No']['job_title_edit']
sd_freq = frequent_words(s, nw, n)
sd_freq_w = [x[0] for x in sd_freq]

print(f'Most frequent words for jobs WITHOUT sustainability in them: \n{sd_freq}')

sdt_freq = []
for t in st_freq:
    if t[0] in sd_freq_w:
        sdt_freq.append(t[0])

sdt_freq
# Out:
# Number of rows included in analysis: 237
# Most frequent words for jobs WITH sustainability in them:
# [('Manager', 51), ('Environmental', 27), ('Director', 23), ('Specialist', 21), ('Analyst', 18), ('Consultant', 18), ('Engineer', 18), ('Coordinator', 16), ('Energy', 14), ('Senior', 13)]
#
# Number of rows included in analysis: 436
# Most frequent words for jobs WITHOUT sustainability in them:
# [('Environmental', 68), ('Specialist', 47), ('Analyst', 46), ('Associate', 43), ('Manager', 41), ('Intern', 24), ('Coordinator', 24), ('Program', 23), ('Assistant', 23), ('Research', 22)]
# ['Manager', 'Environmental', 'Specialist', 'Analyst', 'Coordinator']

# %%
#Graphing the frequent words seen in job titles with sustainability
x = [word[0] for word in st_freq[:5]]
y = [word[1] for word in st_freq[:5]]

ct_colors = ['darkgreen' if x in sdt_freq else 'mediumseagreen' for x in st_freq_w]
plt.rcParams.update({'font.size': 12})
plt.title("Frequent words - Job Titles with Sustainability (n=237)")
plt.barh(x, y, color = ct_colors)
plt.gca().invert_yaxis()
plt.gca().set_xlabel('Frequency')

plt.show()

# %%
#Creating column with edited job description
load_data['job_desc_edit'] = [re.sub(r'\n', ' ', str(x)).strip().lower() for x in load_data['job_descriptions']]
load_data
# Out:
#                                              job_title  \
# 0                                Sustainability Intern
# 1              Environmental Sustainability Internship
# 2                               SUSTAINABILITY ANALYST
# 3                 Sustainability Innovation Consultant
# 4                             Sustainability Associate
# ..                                                 ...
# 668  Staff Sustainability Strategy & Disclosure Con...
# 669                     ESG and Sustainability Manager
# 670                            Manager, Sustainability
# 671  Associate Consultant, Sustainability & Social ...
# 672  Environmental Stewardship & Sustainability Ana...
#
#                                         location           job_key  \
# 0                                         Remote  f5438de8a8e1629a
# 1                                 Providence, RI  7075a3a7b5571059
# 2                                     Austin, TX  2171570f88a3a65d
# 3                                         Remote  e862369e52ce2651
# 4                                 Louisville, KY  00a0e465fe8342c8
# ..                                           ...               ...
# 668         Washington, DC 20036 (Downtown area)  037f3323b9192c81
# 669                                   Denver, CO  cf4d4f9e0009297a
# 670                                    Omaha, NE  cc7e05bf63d6cb1d
# 671  New York, NY 10010 (Flatiron District area)  cf188c93641c2e26
# 672                               Queen Anne, WA  2fc2a329bf2d43fc
#
#                                       job_descriptions  \
# 0    About Imperfect\nImperfect Foods was founded i...
# 1    About:  Jellyfish is a newly founded venture t...
# 2    Austin, USA\nLongevity Partners is a boutique ...
# 3    7+ years of experience in consulting, solution...
# 4    Schneider Electric™ creates connected technolo...
# ..                                                 ...
# 668  ERM is seeking a motivated and dynamic Sustain...
# 669  Discover your full potential. At Tetra Tech, w...
# 670  Department FMP-Administration 50000761 Busines...
# 671  APCO Impact is a unique consultancy that takes...
# 672  Job SummaryWe offer competitive salary, great ...
#
#                               company_name                   ceo  founded  \
# 0                          Imperfect Foods           Philip Behn     2015
# 1                                Jellyfish                    -1     2005
# 2                       Longevity Partners                    -1       -1
# 3                Amazon Web Services, Inc.                    -1       -1
# 4                       Schneider Electric  Jean-Pascal Tricoire       -1
# ..                                     ...                   ...      ...
# 668                              Erm Group                    -1     1971
# 669                             Tetra Tech        Dan L. Batrack     1966
# 670  University Of Nebraska Medical Center                    -1     1995
# 671                         Apco Worldwide                    -1     1984
# 672              Seattle Housing Authority                    -1     1939
#
#                  size               revenue  \
# 0       1001 to 5,000   less than $1M (USD)
# 1           51 to 200     $5M to $25M (USD)
# 2            11 to 50                    -1
# 3                  -1                    -1
# 4    more than 10,000  more than $10B (USD)
# ..                ...                   ...
# 668     1001 to 5,000  $100M to $500M (USD)
# 669  more than 10,000      $1B to $5B (USD)
# 670   5,001 to 10,000  $100M to $500M (USD)
# 671      501 to 1,000   $25M to $100M (USD)
# 672      501 to 1,000   less than $1M (USD)
#
#                                  industry  \
# 0                           Manufacturing
# 1              Restaurants & Food Service
# 2                                      -1
# 3                  Information Technology
# 4              Energy, Mining & Utilities
# ..                                    ...
# 668                         HR Consulting
# 669  Architectural & Engineering Services
# 670                             Education
# 671                 Media & Communication
# 672                                    -1
#
#                                         job_title_edit sust_title  \
# 0                                Sustainability Intern        Yes
# 1              Environmental Sustainability Internship        Yes
# 2                               Sustainability Analyst        Yes
# 3                 Sustainability Innovation Consultant        Yes
# 4                             Sustainability Associate        Yes
# ..                                                 ...        ...
# 668  Staff Sustainability Strategy & Disclosure Con...        Yes
# 669                     Esg And Sustainability Manager        Yes
# 670                            Manager, Sustainability        Yes
# 671  Associate Consultant, Sustainability & Social ...        Yes
# 672  Environmental Stewardship & Sustainability Ana...        Yes
#
#     location_edit sust_desc size_category     rev_category  \
# 0          Remote       Yes         large   Less than \$1M
# 1              RI       Yes        medium   \$1M to \$100M
# 2              TX       Yes         small              n/a
# 3          Remote       Yes           n/a              n/a
# 4              KY       Yes    very large  More than \$10B
# ..            ...       ...           ...              ...
# 668            DC       Yes         large   \$100M to \$1B
# 669            CO       Yes    very large    \$1B to \$10B
# 670            NE       Yes    very large   \$100M to \$1B
# 671            NY       Yes         large   \$1M to \$100M
# 672            WA       Yes         large   Less than \$1M
#
#                                          job_desc_edit
# 0    about imperfect imperfect foods was founded in...
# 1    about:  jellyfish is a newly founded venture t...
# 2    austin, usa longevity partners is a boutique s...
# 3    7+ years of experience in consulting, solution...
# 4    schneider electric™ creates connected technolo...
# ..                                                 ...
# 668  erm is seeking a motivated and dynamic sustain...
# 669  discover your full potential. at tetra tech, w...
# 670  department fmp-administration 50000761 busines...
# 671  apco impact is a unique consultancy that takes...
# 672  job summarywe offer competitive salary, great ...
#
# [673 rows x 17 columns]

# %%
#Creating column to indicate whether it has the words "Environmental", "Specialist", "Analyst", "Manager"
load_data['environmental'] = ['Yes' if "environmental" in x.lower() else 'No' for x in load_data['job_title']]
load_data['specialist'] = ['Yes' if "specialist" in x.lower() else 'No' for x in load_data['job_title']]
load_data['analyst'] = ['Yes' if "analyst" in x.lower() else 'No' for x in load_data['job_title']]
load_data['manager'] = ['Yes' if "manager" in x.lower() else 'No' for x in load_data['job_title']]
load_data['engineer'] = ['Yes' if "engineer" in x.lower() else 'No' for x in load_data['job_title']]
load_data
# Out:
#                                              job_title  \
# 0                                Sustainability Intern
# 1              Environmental Sustainability Internship
# 2                               SUSTAINABILITY ANALYST
# 3                 Sustainability Innovation Consultant
# 4                             Sustainability Associate
# ..                                                 ...
# 668  Staff Sustainability Strategy & Disclosure Con...
# 669                     ESG and Sustainability Manager
# 670                            Manager, Sustainability
# 671  Associate Consultant, Sustainability & Social ...
# 672  Environmental Stewardship & Sustainability Ana...
#
#                                         location           job_key  \
# 0                                         Remote  f5438de8a8e1629a
# 1                                 Providence, RI  7075a3a7b5571059
# 2                                     Austin, TX  2171570f88a3a65d
# 3                                         Remote  e862369e52ce2651
# 4                                 Louisville, KY  00a0e465fe8342c8
# ..                                           ...               ...
# 668         Washington, DC 20036 (Downtown area)  037f3323b9192c81
# 669                                   Denver, CO  cf4d4f9e0009297a
# 670                                    Omaha, NE  cc7e05bf63d6cb1d
# 671  New York, NY 10010 (Flatiron District area)  cf188c93641c2e26
# 672                               Queen Anne, WA  2fc2a329bf2d43fc
#
#                                       job_descriptions  \
# 0    About Imperfect\nImperfect Foods was founded i...
# 1    About:  Jellyfish is a newly founded venture t...
# 2    Austin, USA\nLongevity Partners is a boutique ...
# 3    7+ years of experience in consulting, solution...
# 4    Schneider Electric™ creates connected technolo...
# ..                                                 ...
# 668  ERM is seeking a motivated and dynamic Sustain...
# 669  Discover your full potential. At Tetra Tech, w...
# 670  Department FMP-Administration 50000761 Busines...
# 671  APCO Impact is a unique consultancy that takes...
# 672  Job SummaryWe offer competitive salary, great ...
#
#                               company_name                   ceo  founded  \
# 0                          Imperfect Foods           Philip Behn     2015
# 1                                Jellyfish                    -1     2005
# 2                       Longevity Partners                    -1       -1
# 3                Amazon Web Services, Inc.                    -1       -1
# 4                       Schneider Electric  Jean-Pascal Tricoire       -1
# ..                                     ...                   ...      ...
# 668                              Erm Group                    -1     1971
# 669                             Tetra Tech        Dan L. Batrack     1966
# 670  University Of Nebraska Medical Center                    -1     1995
# 671                         Apco Worldwide                    -1     1984
# 672              Seattle Housing Authority                    -1     1939
#
#                  size               revenue  \
# 0       1001 to 5,000   less than $1M (USD)
# 1           51 to 200     $5M to $25M (USD)
# 2            11 to 50                    -1
# 3                  -1                    -1
# 4    more than 10,000  more than $10B (USD)
# ..                ...                   ...
# 668     1001 to 5,000  $100M to $500M (USD)
# 669  more than 10,000      $1B to $5B (USD)
# 670   5,001 to 10,000  $100M to $500M (USD)
# 671      501 to 1,000   $25M to $100M (USD)
# 672      501 to 1,000   less than $1M (USD)
#
#                                  industry  ... location_edit sust_desc  \
# 0                           Manufacturing  ...        Remote       Yes
# 1              Restaurants & Food Service  ...            RI       Yes
# 2                                      -1  ...            TX       Yes
# 3                  Information Technology  ...        Remote       Yes
# 4              Energy, Mining & Utilities  ...            KY       Yes
# ..                                    ...  ...           ...       ...
# 668                         HR Consulting  ...            DC       Yes
# 669  Architectural & Engineering Services  ...            CO       Yes
# 670                             Education  ...            NE       Yes
# 671                 Media & Communication  ...            NY       Yes
# 672                                    -1  ...            WA       Yes
#
#     size_category     rev_category  \
# 0           large   Less than \$1M
# 1          medium   \$1M to \$100M
# 2           small              n/a
# 3             n/a              n/a
# 4      very large  More than \$10B
# ..            ...              ...
# 668         large   \$100M to \$1B
# 669    very large    \$1B to \$10B
# 670    very large   \$100M to \$1B
# 671         large   \$1M to \$100M
# 672         large   Less than \$1M
#
#                                          job_desc_edit environmental  \
# 0    about imperfect imperfect foods was founded in...            No
# 1    about:  jellyfish is a newly founded venture t...           Yes
# 2    austin, usa longevity partners is a boutique s...            No
# 3    7+ years of experience in consulting, solution...            No
# 4    schneider electric™ creates connected technolo...            No
# ..                                                 ...           ...
# 668  erm is seeking a motivated and dynamic sustain...            No
# 669  discover your full potential. at tetra tech, w...            No
# 670  department fmp-administration 50000761 busines...            No
# 671  apco impact is a unique consultancy that takes...            No
# 672  job summarywe offer competitive salary, great ...           Yes
#
#     specialist analyst manager engineer
# 0           No      No      No       No
# 1           No      No      No       No
# 2           No     Yes      No       No
# 3           No      No      No       No
# 4           No      No      No       No
# ..         ...     ...     ...      ...
# 668         No      No      No       No
# 669         No      No     Yes       No
# 670         No      No     Yes       No
# 671         No      No      No       No
# 672         No     Yes      No       No
#
# [673 rows x 22 columns]

# %%
#Graphing the frequent words seen in job titles without sustainability
x = [word[0] for word in sd_freq[:5]]
y = [word[1] for word in sd_freq[:5]]

cd_colors = ['royalblue' if x in sdt_freq else 'lightskyblue' for x in sd_freq_w]

plt.rcParams.update({'font.size': 12})
plt.title("Frequent words - Job Titles without Sustainability (n=436)")
plt.barh(x, y, color = cd_colors)
plt.gca().invert_yaxis()
plt.gca().set_xlabel('Frequency')

plt.show()

# %%
#Graphing the frequent words seen in jobs where 'sustainability' did not show up in title or description
s = load_data[(load_data['sust_title'] == 'No') & (load_data['sust_desc'] == 'No')]['job_title_edit']
ndt_freq = frequent_words(s, notWords = [' ', 'entry', 'level'])

print(f'Most frequent words for jobs WITHOUT sustainability in them: \n{ndt_freq}')

x = [word[0] for word in ndt_freq]
y = [word[1] for word in ndt_freq]

plt.title("Frequent words - Job Titles & Desc without Sustainability (n=44)")
plt.barh(x, y, color = 'gray')
plt.gca().invert_yaxis()
plt.gca().set_xlabel('Frequency')

plt.show()
# Out:
# Number of rows included in analysis: 44
# Most frequent words for jobs WITHOUT sustainability in them:
# [('Environmental', 44), ('Specialist', 28), ('Analyst', 14), ('Scientist', 5), ('Protection', 4), ('Health', 4), ('Wetland', 3), ('Historic', 3), ('Preservation', 3), ('Ii', 3)]

# %%
# Map Guide - https://towardsdatascience.com/mapping-with-matplotlib-pandas-geopandas-and-basemap-in-python-d11b57ab5dac

#"sustainability" job titles, where are they located?
# Map Sourc: https://hub.arcgis.com/datasets/1b02c87f62d24508970dc1a6df80c98e_0?geometry=136.684%2C29.346%2C-21.871%2C67.392
fp = ".\states-shapes\States_shapefile.shp"

map_df = gpd.read_file(fp)
map_df.drop('Program', axis=1, inplace= True)
map_df.drop('State_Name', axis=1, inplace=True)
map_df.rename(columns = {'State_Code':'location_edit'}, inplace=True)


#df is groupby location_edit (states) and count
df = load_data.loc[:,['company_name','location_edit']].groupby('location_edit').count()

merged = map_df.join(df, on = 'location_edit', how = 'left')
merged.loc[:,'company_name'] = merged.loc[:,'company_name'].replace(np.nan, 0)
merged[0:8]

variable = 'company_name'

cmin, cmax = 0, 40

fig, ax = plt.subplots(1, figsize = (10,5))
merged.plot(column=variable, cmap='BuGn', linewidth = 0.8, ax = ax, edgecolor = '0.8')

ax.set_title('Frequency of All Jobs" (n=673)')
ax.set_yticklabels([])
ax.set_xticklabels([])
ax.set_ylim(20,55)
ax.set_xlim(-130,-65)
ax.annotate('Source: services2.arcgis.com', xy=(0.07,0.11), xycoords = 'figure fraction', horizontalalignment = 'left', verticalalignment = 'top', color = '#555555')

#colorbar as a legend
# Create colorbar as a legend
sm = plt.cm.ScalarMappable(cmap='BuGn', norm=plt.Normalize(vmin=cmin, vmax=cmax))
# empty array for the data range
sm._A = []
# add the colorbar to the figure
cbar = fig.colorbar(sm)

# %%
df = load_data.loc[load_data['sust_title'] == 'Yes',['company_name','location_edit']].groupby('location_edit').count().sort_values('company_name', ascending = False)
df[:5]
# Out:
#                company_name
# location_edit
# CA                       39
# TX                       20
# NY                       17
# WA                       16
# MA                       16

# %%
#categorizing jobs by industry. indeed has 62 industries. 137 jobs are n/a.
load_data['industry'].unique()
#jobs with sustainability in the title
print('Jobs with Sustainability in Title')
print(load_data.loc[load_data['sust_title'] == 'Yes',['industry','location_edit']].groupby(['industry']).count().sort_values(by="location_edit",ascending=False)[:4])
#jobs with sustainability NOT in the title - is 'sustainability' the right word to search?
print('\nJobs without Sustainability in Title')
print(load_data.loc[load_data['sust_title'] == 'No',['industry','location_edit']].groupby(['industry']).count().sort_values(by="location_edit",ascending=False)[:4])
#all jobs that show up when we search 'sustainability' on indeed
print('\nall jobs')
print(load_data.loc[:,['industry','location_edit']].groupby(['industry']).count().sort_values(by="location_edit",ascending=False)[:4])

n_groups = 3
# Out:
# Jobs with Sustainability in Title
#                         location_edit
# industry
# -1                                 47
# Manufacturing                      30
# Healthcare                         18
# Information Technology             17
#
# Jobs without Sustainability in Title
#                     location_edit
# industry
# -1                             90
# Manufacturing                  51
# Retail & Wholesale             34
# Education                      32
#
# all jobs
#                                     location_edit
# industry
# -1                                            137
# Manufacturing                                  81
# Education                                      44
# Government & Public Administration             43

# %%
#categorizing jobs by employee size
load_data['size_category'].unique()
#jobs with sustainability in the title
print('Jobs with Sustainability in Title')
print(load_data.loc[load_data['sust_title'] == 'Yes',['size_category','industry']].groupby(['size_category']).count().sort_values(by="industry",ascending=False)[:10])
# #jobs with sustainability NOT in the title - is 'sustainability' the right word to search?
print('\nJobs without Sustainability in Title')
print(load_data.loc[load_data['sust_title'] == 'No',['size_category','industry']].groupby(['size_category']).count().sort_values(by="industry",ascending=False)[:10])
# #all jobs that show up when we search 'sustainability' on indeed
print('\nall jobs')
print(load_data.loc[:,['size_category','industry']].groupby(['size_category']).count().sort_values(by="industry",ascending=False)[:10])
# Out:
# Jobs with Sustainability in Title
#                industry
# size_category
# very large           98
# large                61
# n/a                  41
# small                18
# medium               15
# very small            4
#
# Jobs without Sustainability in Title
#                industry
# size_category
# very large          180
# n/a                 107
# large                70
# medium               46
# small                18
# very small           15
#
# all jobs
#                industry
# size_category
# very large          278
# n/a                 148
# large               131
# medium               61
# small                36
# very small           19

# %%
#categorizing jobs by revenue.
load_data['rev_category'].unique()
# jobs with sustainability in the title
print('Jobs with Sustainability in Title')
print(load_data.loc[load_data['sust_title'] == 'Yes',['rev_category','industry']].groupby(['rev_category']).count().sort_values(by="industry",ascending=False)[:10])
# #jobs with sustainability NOT in the title - is 'sustainability' the right word to search?
print('\nJobs without Sustainability in Title')
print(load_data.loc[load_data['sust_title'] == 'No',['rev_category','industry']].groupby(['rev_category']).count().sort_values(by="industry",ascending=False)[:10])
# #all jobs that show up when we search 'sustainability' on indeed
print('\nall jobs')
print(load_data.loc[:,['rev_category','industry']].groupby(['rev_category']).count().sort_values(by="industry",ascending=False)[:10])
# Out:
# Jobs with Sustainability in Title
#                  industry
# rev_category
# n/a                    66
# More than \$10B        57
# \$1B to \$10B          42
# \$100M to \$1B         38
# \$1M to \$100M         27
# Less than \$1M          7
#
# Jobs without Sustainability in Title
#                  industry
# rev_category
# n/a                   162
# More than \$10B        98
# \$1B to \$10B          68
# \$1M to \$100M         59
# \$100M to \$1B         35
# Less than \$1M         14
#
# all jobs
#                  industry
# rev_category
# n/a                   228
# More than \$10B       155
# \$1B to \$10B         110
# \$1M to \$100M         86
# \$100M to \$1B         73
# Less than \$1M         21

# %% [markdown]
# ### Creating Word Clouds - frequent words

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
# DEFINE THE DATAFRAME YOU WANT TO ANALYZE HERE
desc_df = load_data.loc[(load_data['sust_title'] == 'No') & (load_data['sust_desc'] == 'No')]
desc_df.reset_index(inplace=True)

# SPECIFY THE SERIES YOU WANT IN THE WORD CLOUD
descriptions = desc_df['job_descriptions']
desc_df
# Out:
#     index                                          job_title  \
# 0       5                Environmental Protection Specialist
# 1      26                    ENVIRONMENTAL HEALTH SPECIALIST
# 2      93      Economic Analyst - Environmental (Austin, TX)
# 3     102                Environmental Protection Specialist
# 4     124                              Environmental Analyst
# 5     165                              Environmental Analyst
# 6     185         Environmental Scientist/Wetland Specialist
# 7     192               Entry Level Environmental Specialist
# 8     196  Manager, Environmental and Geoscience Subject ...
# 9     199            Environmental Communications Specialist
# 10    203         Environmental Scientist/Wetland Specialist
# 11    204  FEMA Disaster Environmental Historic Preservat...
# 12    218           Environmental Scientist / GIS Specialist
# 13    219  FEMA Disaster Environmental Historic Preservat...
# 14    253                       Environmental Health Analyst
# 15    292                      Environmental Markets Analyst
# 16    293    Environmental Scientist & Specialist - Advanced
# 17    301               ENVIRONMENTAL SCIENCE SPECIALIST 3/4
# 18    302                           Environmental Analyst II
# 19    334  Environmental Monitoring Analyst - 12 hour nig...
# 20    335         Environmental Scientist/Wetland Specialist
# 21    361  Environmental and Historic Preservation (EHP) ...
# 22    368              Environmental Compliance Specialist I
# 23    379  Environmental Protection Specialist (Open to b...
# 24    388                            Environmental Analyst V
# 25    395                    Global Environmental Specialist
# 26    402                              Environmental Analyst
# 27    416        Inorganics Specialist/Environmental Chemist
# 28    444                              Environmental Analyst
# 29    464      Economic Analyst - Environmental (Austin, TX)
# 30    480                           Environmental Specialist
# 31    481                Environmental Compliance Specialist
# 32    493                      Environmental Program Analyst
# 33    498               Entry Level Environmental Specialist
# 34    500                      Environmental Analyst, Senior
# 35    502               Entry Level Environmental Specialist
# 36    504                      Environmental Analyst, Senior
# 37    520  Environmental Scientist/ Environmental Specialist
# 38    524                       GIS Environmental Specialist
# 39    528           Environmental Health & Safety Specialist
# 40    538  Sustainable Growth & Development, Research Ass...
# 41    557                Environmental Protection Specialist
# 42    586            Environmental Health Specialist I or II
# 43    660                  Environmental Specialist Level II
#
#                                     location           job_key  \
# 0   Washington, DC 20505 (Foggy Bottom area)  77d2cc7befc9e0ac
# 1                           Durham, NC 27701  aca7216abae9a4be
# 2                                 Austin, TX  32bb55f4146143c7
# 3                             Washington, DC  0d072daade43f6ab
# 4                             Washington, DC  807ecbb8599858b8
# 5                             Greenville, SC  1b7e8ee6bf0392d6
# 6                                Seattle, WA  49b05360891294a1
# 7                         Manassas, VA 20109  46305277fd7507c0
# 8          Chicago, IL 60601 (The Loop area)  6abb8fd29ca2f89b
# 9                              Arlington, VA  bac53af1c420d1ac
# 10                               Seattle, WA  49b05360891294a1
# 11           Boise, ID 83702 (Downtown area)  64612f844a56967e
# 12                            Binghamton, NY  ed3fac7c3e33090d
# 13           Boise, ID 83702 (Downtown area)  64612f844a56967e
# 14  Las Vegas, NV 89110 (Sunrise Manor area)  c988d214e17c3ef5
# 15                                    Remote  8110a3a23ad839da
# 16                        Santa Fe, NM 87505  67e2900dd74d3792
# 17     Phoenix, AZ 85007 (Central City area)  c925b3320ffd89b6
# 18         Lincoln, NE 68508 (Downtown area)  3db268c67e7e4e3d
# 19                           Rocky Mount, NC  10a02e3a3062f85d
# 20  Indianapolis, IN 46250 (Fall Creek area)  e4c85f6ab7027981
# 21                            New York State  4cb5954e9064285b
# 22                              Richmond, VA  20e178127ec9f5be
# 23                              Richmond, VA  e95a375586143653
# 24                         West Boylston, MA  d056cd454fe49c27
# 25                         Houston, TX 77086  7b811aec85a2a0f6
# 26                     West Seneca, NY 14224  76c8bf7f3786d473
# 27                            Holt, MI 48842  06f26f58b536910c
# 28                       San Diego, CA 92123  c4daf6515f88f6c5
# 29                                Austin, TX  32bb55f4146143c7
# 30                               Houston, TX  71926edb86cf92ad
# 31                       Las Vegas, NV 89115  224585c8a2003faa
# 32                       St. Louis, MO 63125  43b42d1e5a119b21
# 33                        Manassas, VA 20109  46305277fd7507c0
# 34                            Cumberland, RI  9bfd87f41deeeeec
# 35                        Manassas, VA 20109  46305277fd7507c0
# 36                            Cumberland, RI  9bfd87f41deeeeec
# 37                            Foxborough, MA  df8ae3e1f57d6c9b
# 38                      Juno Beach, FL 33408  b68498001f4a4bdb
# 39                            Stillwater, MN  dbdc17ce8a6f9077
# 40  Los Angeles, CA 90045 (Westchester area)  0a98b712d6623e04
# 41                            Washington, DC  0d072daade43f6ab
# 42                       Pendleton, OR 97801  a518abf5e5535f4a
# 43                              Monrovia, CA  2de7b3821880203c
#
#                                      job_descriptions  \
# 0   Environmental Protection Specialists support t...
# 1   Durham County Government employs approximately...
# 2   Description\nWe have an opening for an Environ...
# 3   Duties\nSummary\nThe individual serves as an E...
# 4   ERG has an immediate opening for a bright, mot...
# 5   Fungal spore identification and other microbio...
# 6   Environmental Scientist/Wetland Specialist – B...
# 7   Requisition Number – 21-003\nPost Date – 4/1/2...
# 8   Known for being a great place to work and buil...
# 9   If you have a background in environmental scie...
# 10  Environmental Scientist/Wetland Specialist – B...
# 11  Our People & Places Solutions business – reinf...
# 12  LaBella Associates was established in 1978 and...
# 13  Our People & Places Solutions business – reinf...
# 14  Definition\nAuthorization to work in the Unite...
# 15  Environmental Markets Analyst\nThe Earth Partn...
# 16  Salary\n\n$20.23 - $35.21 Hourly\n$42,088 - $7...
# 17  The Environmental Scientist will function as a...
# 18  Examples of Work\nUnder limited supervision, p...
# 19  ROLE SUMMARY\nThe Environmental Monitoring (EM...
# 20  Job SummaryThe role of Environmental Scientist...
# 21  Environmental and Historic Preservation (EHP) ...
# 22  At Aqua, a subsidiary of Essential Utilities, ...
# 23  Duties\nSummary\nYou will serve as the technic...
# 24  The Department of Conservation and Recreation ...
# 25  Overview:\nThe role proactively supports Lufki...
# 26  TRC Companies, Inc., a pioneer in groundbreaki...
# 27  Inorganics Specialist/Environmental ChemistPos...
# 28  Overview / Responsibilities:\n\nWood Environme...
# 29  Description\nWe have an opening for an Environ...
# 30  Environmental Specialist\nESC Polytech Consult...
# 31  The Oneida ESC Group is a family of companies ...
# 32  Job Position Number: SLR0061\n\nSalary: $1,422...
# 33  Requisition Number – 21-003\nPost Date – 4/1/2...
# 34  Primary responsibilities of the Environmental ...
# 35  Requisition Number – 21-003\nPost Date – 4/1/2...
# 36  Primary responsibilities of the Environmental ...
# 37  Environmental Scientist/ Environmental Special...
# 38  Requisition ID: 51658\nNextEra Energy Resource...
# 39  Your MissionOverviewFor over 40 years, DiaSori...
# 40  Sustainable Growth & Development, Research Ass...
# 41  Duties\nSummary\nThe individual serves as an E...
# 42  I –$4,301.00/ MonthII- $4,633.00/MonthUse of U...
# 43  48,000 people. 49 countries. Over 120 office l...
#
#                          company_name                           ceo  founded  \
# 0         Central Intelligence Agency                   David Cohen     1947
# 1                       Durham County                            -1       -1
# 2                   Burns & Mcdonnell                            -1     1898
# 3     Us Surface Transportation Board                            -1       -1
# 4        Eastern Research Group, Inc.                            -1       -1
# 5                               Seeml                            -1       -1
# 6                 Hamer Environmental                            -1       -1
# 7            Rinker Design Associates                            -1       -1
# 8                                Kpmg                   Bill Thomas     1987
# 9        Eastern Research Group, Inc.                            -1       -1
# 10                Hamer Environmental                            -1       -1
# 11                             Jacobs           Steven J. Demetriou     1947
# 12                 Labella Associates                            -1     1978
# 13                             Jacobs           Steven J. Demetriou     1947
# 14    Southern Nevada Health District                            -1       -1
# 15                 The Earth Partners                            -1       -1
# 16                State Of New Mexico        Michelle Lujan Grisham       -1
# 17                   State Of Arizona                    Doug Ducey       -1
# 18                  State Of Nebraska        Governor Pete Ricketts       -1
# 19                             Pfizer     ALBERT BOURLA, DVM, PH.D.     1849
# 20          Metric Environmental, Llc                            -1       -1
# 21                                Brs                            -1       -1
# 22                 Aqua America, Inc.                            -1     1968
# 23  Us Federal Highway Administration                            -1       -1
# 24     Dcr- Water Supply & Protection                            -1       -1
# 25                  Lufkin Industries                            -1       -1
# 26                  Trc Companies Inc         Christopher P. Vincze     1969
# 27    Fibertec Environmental Services                            -1       -1
# 28                           Wood Plc                  Robin Watson       -1
# 29                  Burns & Mcdonnell                            -1     1898
# 30           Esc Polytech Consultants                            -1       -1
# 31                   Oneida Esc Group                            -1       -1
# 32                  State Of Missouri          Governor Mike Parson       -1
# 33           Rinker Design Associates                            -1       -1
# 34                         Cvs Health  Karen S. Lynch, President &      1963
# 35           Rinker Design Associates                            -1       -1
# 36                         Cvs Health  Karen S. Lynch, President &      1963
# 37              Power Engineers, Inc.                            -1     1976
# 38                     Nextera Energy                 James L. Robo     1925
# 39                           Diasorin                    Carlo Rosa     1968
# 40              Beacon Economics, Llc                            -1       -1
# 41    Us Surface Transportation Board                            -1       -1
# 42                    Umatilla County                            -1       -1
# 43                             Worley                            -1     1971
#
#                 size               revenue  ... location_edit sust_desc  \
# 0   more than 10,000                    -1  ...            DC        No
# 1          51 to 200      $1M to $5M (USD)  ...            NC        No
# 2    5,001 to 10,000      $1B to $5B (USD)  ...            TX        No
# 3                 -1                    -1  ...            DC        No
# 4                 -1                    -1  ...            DC        No
# 5       less than 10   less than $1M (USD)  ...            SC        No
# 6                 -1                    -1  ...            WA        No
# 7                 -1                    -1  ...            VA        No
# 8   more than 10,000      $1B to $5B (USD)  ...            IL        No
# 9                 -1                    -1  ...            VA        No
# 10                -1                    -1  ...            WA        No
# 11  more than 10,000  more than $10B (USD)  ...            ID        No
# 12                -1                    -1  ...            NY        No
# 13  more than 10,000  more than $10B (USD)  ...            ID        No
# 14      501 to 1,000   $25M to $100M (USD)  ...            NV        No
# 15                -1                    -1  ...        Remote        No
# 16  more than 10,000                    -1  ...            NM        No
# 17  more than 10,000  more than $10B (USD)  ...            AZ        No
# 18  more than 10,000                    -1  ...            NE        No
# 19  more than 10,000     $5B to $10B (USD)  ...            NC        No
# 20          11 to 50   less than $1M (USD)  ...            IN        No
# 21                -1                    -1  ...            NY        No
# 22     1001 to 5,000    $500M to $1B (USD)  ...            VA        No
# 23                -1                    -1  ...            VA        No
# 24                -1                    -1  ...            MA        No
# 25      501 to 1,000                    -1  ...            TX        No
# 26     1001 to 5,000  $100M to $500M (USD)  ...            NY        No
# 27                -1                    -1  ...            MI        No
# 28  more than 10,000  more than $10B (USD)  ...            CA        No
# 29   5,001 to 10,000      $1B to $5B (USD)  ...            TX        No
# 30                -1                    -1  ...            TX        No
# 31                -1                    -1  ...            NV        No
# 32     1001 to 5,000                    -1  ...            MO        No
# 33                -1                    -1  ...            VA        No
# 34  more than 10,000  more than $10B (USD)  ...            RI        No
# 35                -1                    -1  ...            VA        No
# 36  more than 10,000  more than $10B (USD)  ...            RI        No
# 37     1001 to 5,000    $500M to $1B (USD)  ...            MA        No
# 38  more than 10,000      $1B to $5B (USD)  ...            FL        No
# 39     1001 to 5,000                    -1  ...            MN        No
# 40          11 to 50   less than $1M (USD)  ...            CA        No
# 41                -1                    -1  ...            DC        No
# 42                -1                    -1  ...            OR        No
# 43  more than 10,000      $1B to $5B (USD)  ...            CA        No
#
#    size_category     rev_category  \
# 0     very large              n/a
# 1         medium   \$1M to \$100M
# 2     very large    \$1B to \$10B
# 3            n/a              n/a
# 4            n/a              n/a
# 5     very small   Less than \$1M
# 6            n/a              n/a
# 7            n/a              n/a
# 8     very large    \$1B to \$10B
# 9            n/a              n/a
# 10           n/a              n/a
# 11    very large  More than \$10B
# 12           n/a              n/a
# 13    very large  More than \$10B
# 14         large   \$1M to \$100M
# 15           n/a              n/a
# 16    very large              n/a
# 17    very large  More than \$10B
# 18    very large              n/a
# 19    very large    \$1B to \$10B
# 20         small   Less than \$1M
# 21           n/a              n/a
# 22         large   \$100M to \$1B
# 23           n/a              n/a
# 24           n/a              n/a
# 25         large              n/a
# 26         large   \$100M to \$1B
# 27           n/a              n/a
# 28    very large  More than \$10B
# 29    very large    \$1B to \$10B
# 30           n/a              n/a
# 31           n/a              n/a
# 32         large              n/a
# 33           n/a              n/a
# 34    very large  More than \$10B
# 35           n/a              n/a
# 36    very large  More than \$10B
# 37         large   \$100M to \$1B
# 38    very large    \$1B to \$10B
# 39         large              n/a
# 40         small   Less than \$1M
# 41           n/a              n/a
# 42           n/a              n/a
# 43    very large    \$1B to \$10B
#
#                                         job_desc_edit environmental  \
# 0   environmental protection specialists support t...           Yes
# 1   durham county government employs approximately...           Yes
# 2   description we have an opening for an environm...           Yes
# 3   duties summary the individual serves as an env...           Yes
# 4   erg has an immediate opening for a bright, mot...           Yes
# 5   fungal spore identification and other microbio...           Yes
# 6   environmental scientist/wetland specialist – b...           Yes
# 7   requisition number – 21-003 post date – 4/1/20...           Yes
# 8   known for being a great place to work and buil...           Yes
# 9   if you have a background in environmental scie...           Yes
# 10  environmental scientist/wetland specialist – b...           Yes
# 11  our people & places solutions business – reinf...           Yes
# 12  labella associates was established in 1978 and...           Yes
# 13  our people & places solutions business – reinf...           Yes
# 14  definition authorization to work in the united...           Yes
# 15  environmental markets analyst the earth partne...           Yes
# 16  salary  $20.23 - $35.21 hourly $42,088 - $73,2...           Yes
# 17  the environmental scientist will function as a...           Yes
# 18  examples of work under limited supervision, pe...           Yes
# 19  role summary the environmental monitoring (em)...           Yes
# 20  job summarythe role of environmental scientist...           Yes
# 21  environmental and historic preservation (ehp) ...           Yes
# 22  at aqua, a subsidiary of essential utilities, ...           Yes
# 23  duties summary you will serve as the technical...           Yes
# 24  the department of conservation and recreation ...           Yes
# 25  overview: the role proactively supports lufkin...           Yes
# 26  trc companies, inc., a pioneer in groundbreaki...           Yes
# 27  inorganics specialist/environmental chemistpos...           Yes
# 28  overview / responsibilities:  wood environment...           Yes
# 29  description we have an opening for an environm...           Yes
# 30  environmental specialist esc polytech consulta...           Yes
# 31  the oneida esc group is a family of companies ...           Yes
# 32  job position number: slr0061  salary: $1,422.0...           Yes
# 33  requisition number – 21-003 post date – 4/1/20...           Yes
# 34  primary responsibilities of the environmental ...           Yes
# 35  requisition number – 21-003 post date – 4/1/20...           Yes
# 36  primary responsibilities of the environmental ...           Yes
# 37  environmental scientist/ environmental special...           Yes
# 38  requisition id: 51658 nextera energy resources...           Yes
# 39  your missionoverviewfor over 40 years, diasori...           Yes
# 40  sustainable growth & development, research ass...            No
# 41  duties summary the individual serves as an env...           Yes
# 42  i –$4,301.00/ monthii- $4,633.00/monthuse of u...           Yes
# 43  48,000 people. 49 countries. over 120 office l...           Yes
#
#    specialist analyst manager engineer
# 0         Yes      No      No       No
# 1         Yes      No      No       No
# 2          No     Yes      No       No
# 3         Yes      No      No       No
# 4          No     Yes      No       No
# 5          No     Yes      No       No
# 6         Yes      No      No       No
# 7         Yes      No      No       No
# 8         Yes      No     Yes       No
# 9         Yes      No      No       No
# 10        Yes      No      No       No
# 11        Yes      No      No       No
# 12        Yes      No      No       No
# 13        Yes      No      No       No
# 14         No     Yes      No       No
# 15         No     Yes      No       No
# 16        Yes      No      No       No
# 17        Yes      No      No       No
# 18         No     Yes      No       No
# 19         No     Yes      No       No
# 20        Yes      No      No       No
# 21        Yes      No      No       No
# 22        Yes      No      No       No
# 23        Yes      No      No       No
# 24         No     Yes      No       No
# 25        Yes      No      No       No
# 26         No     Yes      No       No
# 27        Yes      No      No       No
# 28         No     Yes      No       No
# 29         No     Yes      No       No
# 30        Yes      No      No       No
# 31        Yes      No      No       No
# 32         No     Yes      No       No
# 33        Yes      No      No       No
# 34         No     Yes      No       No
# 35        Yes      No      No       No
# 36         No     Yes      No       No
# 37        Yes      No      No       No
# 38        Yes      No      No       No
# 39        Yes      No      No       No
# 40         No      No      No       No
# 41        Yes      No      No       No
# 42        Yes      No      No       No
# 43        Yes      No      No       No
#
# [44 rows x 23 columns]

# %%
# function to filter out unwanted words, stop_words, puntuation

def punctuation_stop(text, unwanted):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    unimportant = unwanted
    for w in word_tokens:
        if w not in stop_words and w.isalpha() and w not in unimportant:
            filtered.append(w.lower())
    return filtered

# %%
# generate words for word cloud
# input: series

def forWC(series, unwanted):
    # list of descriptions for each job of interest
    processed_descriptions = []
    for i in range(0, len(descriptions)):
        #Remove all \n
        processed_desc = re.sub(r'\n', ' ', str(descriptions[i]))

        processed_desc = processed_desc.lower()

        processed_descriptions.append(processed_desc)
    
    # preparing the descriptions list for filtering
    words = " ".join(processed_descriptions)
    words_filtered = punctuation_stop(words, unwanted)
    
    # preparing the filtered description for WordCloud
    text = " ".join([ele for ele in words_filtered])
    
    return text

# %%
# DEFINE unwanted words here
# used for sust title yes vs no, sust title yes vs no environmental
# unwanted = [
#     'people', 'team', 'customer', 'client', 
#     'support', 'product', 'projects', 'programs', 
#     'ensure', 'required', 'goal', 'service', 'program', 
#     'provide', 'including', 'company', 'work', 'position', 
#     'employee', 'project', 'experience', 'sustainability', 
#     'provide', 'within', 'well', 'application', 'include', 
#     'industry', 'year', 'ability', 'new', 'part', 'preferred', 'related',
#     'use', 'job', 'must', 'qualification', "environmental", 'regards',
#     'business', 'development', 'management'
# ]

# user for neither analysis
unwanted = [
        'people', 'team', 'customer', 'client', 
        'support', 'product', 'projects', 'programs', 
        'ensure', 'required', 'goal', 'service', 'program', 
        'provide', 'including', 'company', 'work', 'position', 
        'employee', 'project', 'experience', 'sustainability', 
        'provide', 'within', 'well', 'application', 'include', 
        'industry', 'year', 'ability', 'new', 'part', 'preferred', 'related',
        'use', 'job', 'must', 'qualification', 'experience'
]

# #used for manager sust title yes vs no
# unwanted = [
#     'people', 'team', 'customer', 'client', 
#     'support', 'product', 'projects', 'programs', 
#     'ensure', 'required', 'goal', 'service', 'program', 
#     'provide', 'including', 'company', 'work', 'position', 
#     'employee', 'project', 'experience', 'sustainability', 
#     'provide', 'within', 'well', 'application', 'include', 
#     'industry', 'year', 'ability', 'new', 'part', 'preferred', 'related',
#     'use', 'job', 'must', 'qualification', "environmental", 'regards',
#     'manager', 'manage', 'management', 'development', 'business', 'across'
# ]

words = forWC(descriptions, unwanted)

#Creating wordcloud generator
wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 1000, width =1500, height = 1000)

#Actually creating the wordcloud
wc.generate(words)

plt.figure(figsize=[10,10])
plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
plt.savefig('freqwords_neither.jpg')
plt.show()

# %%
# extract the common words in manager, specialist, analyst job descriptions
'''def common_words(cols, unwanted):
    
    updated = []
    
    # we want where cols value is 'Yes'
    for col in cols:
        desc_df = load_data.loc[load_data[col] == 'Yes']
        desc_df.reset_index(inplace=True)
        descriptions = [re.sub(r'\n', ' ', str(x)).lower() for x in desc_df['job_descriptions']]
        
        #join all descriptions in one column into text
        txt_desc = " ".join(descriptions)
        
        unique_words = set(txt_desc.split())
        
        for x in unique_words:
            if x not in updated:
                updated.append(x)
        copy = []
        for y in updated:
            if y in unique_words:
                copy.append(y)
        
        updated = copy
    
    updated_w = " ".join(updated)
    
    words_filtered = punctuation_stop(updated_w, unwanted)

    # preparing the filtered description for WordCloud
    text = set([ele for ele in words_filtered])

    return text

column = ['manager', 'specialist', 'analyst']
ignoreWords = [
    'sustainability', 'environmental'
]
common = common_words(column, ignoreWords)
(common)
'''
# Out:
# {'purchasing',
#  'expectation',
#  'rma',
#  'six',
#  'structured',
#  'configuration',
#  'flexjobs',
#  'minorities',
#  'border',
#  'cj',
#  'actions',
#  'life',
#  'live',
#  'partners',
#  'analysis',
#  'come',
#  'largest',
#  'fulfill',
#  'environmentcursory',
#  'effects',
#  'dedication',
#  'biological',
#  'solicit',
#  'describes',
#  'main',
#  'adapt',
#  'persons',
#  'developing',
#  'last',
#  'contained',
#  'calls',
#  'calculated',
#  'knowledgeable',
#  'instruments',
#  'report',
#  'functional',
#  'management',
#  'next',
#  'protects',
#  'jobsemea',
#  'vehicle',
#  'welcoming',
#  'reinventing',
#  'different',
#  'lindbergh',
#  'due',
#  'equivalent',
#  'gaining',
#  'spatial',
#  'cultivated',
#  'accredited',
#  'thousands',
#  'endowments',
#  'immediately',
#  'stand',
#  'outside',
#  'recruited',
#  'korean',
#  'fossil',
#  'insulet',
#  'dignity',
#  'missional',
#  'creed',
#  'notify',
#  'compensation',
#  'structuring',
#  'operational',
#  'input',
#  'elements',
#  'forests',
#  'necessity',
#  'enables',
#  'push',
#  'needs',
#  'browser',
#  'gatos',
#  'installations',
#  'called',
#  'similar',
#  'powerpoint',
#  'appreciates',
#  'entrepreneurial',
#  'fresh',
#  'revised',
#  'park',
#  'females',
#  'ordinances',
#  'citizencadmus',
#  'cfpk',
#  'owns',
#  'directs',
#  'structures',
#  'permitted',
#  'applications',
#  'examples',
#  'resiliency',
#  'growth',
#  'action',
#  'institute',
#  'counseling',
#  'daily',
#  'visits',
#  'cafeteria',
#  'figures',
#  'marketplace',
#  'describing',
#  'lighting',
#  'vu',
#  'fs',
#  'passionate',
#  'headed',
#  'confidential',
#  'receiving',
#  'dedicated',
#  'identity',
#  'physicians',
#  'settings',
#  'certified',
#  'public',
#  'secondary',
#  'provided',
#  'inherent',
#  'prior',
#  'associations',
#  'identifies',
#  'ready',
#  'often',
#  'contribution',
#  'billion',
#  'disability',
#  'imagining',
#  'comprised',
#  'sampling',
#  'materialsbuilding',
#  'mn',
#  'supervision',
#  'weeks',
#  'alongside',
#  'along',
#  'anne',
#  'teach',
#  'va',
#  'audits',
#  'improved',
#  'waste',
#  'bottoms',
#  'organizes',
#  'hr',
#  'skills',
#  'promotes',
#  'engaging',
#  'inside',
#  'beaman',
#  'scoping',
#  'techniques',
#  'skilled',
#  'mcothron',
#  'joc',
#  'projected',
#  'interdepartmental',
#  'informs',
#  'chief',
#  'courage',
#  'combination',
#  'depth',
#  'perform',
#  'submitted',
#  'fax',
#  'mental',
#  'nashville',
#  'salary',
#  'respects',
#  'brand',
#  'conducting',
#  'skillsworking',
#  'earnings',
#  'eq',
#  'career',
#  'contingent',
#  'achieve',
#  'humanitarian',
#  'guard',
#  'participated',
#  'objectives',
#  'intrusion',
#  'spares',
#  'faculty',
#  'trends',
#  'logically',
#  'heard',
#  'genetic',
#  'internship',
#  'beneficial',
#  'leave',
#  'backorders',
#  'intent',
#  'invite',
#  'agree',
#  'consequence',
#  'acceptance',
#  'billing',
#  'finding',
#  'erps',
#  'process',
#  'equal',
#  'campus',
#  'option',
#  'underrepresented',
#  'delivery',
#  'abide',
#  'symetra',
#  'carries',
#  'missouri',
#  'back',
#  'products',
#  'contracting',
#  'portal',
#  'referral',
#  'economically',
#  'theories',
#  'screen',
#  'effectively',
#  'exams',
#  'reductions',
#  'uses',
#  'specificationsperforms',
#  'designs',
#  'roadway',
#  'movement',
#  'proteins',
#  'tight',
#  'reconciliation',
#  'creates',
#  'tranetrace',
#  'cmms',
#  'studies',
#  'dams',
#  'transform',
#  'rule',
#  'initiatives',
#  'officers',
#  'scientific',
#  'heart',
#  'statutes',
#  'arcgis',
#  'run',
#  'throughout',
#  'distributing',
#  'optimize',
#  'lca',
#  'esg',
#  'whilst',
#  'words',
#  'scheduled',
#  'confidence',
#  'expand',
#  'immigration',
#  'provision',
#  'leveraging',
#  'capable',
#  'colleaguesparticipates',
#  'missions',
#  'environment',
#  'workshops',
#  'uw',
#  'spam',
#  'substantive',
#  'satisfaction',
#  'asks',
#  'middle',
#  'hope',
#  'track',
#  'confident',
#  'remaining',
#  'complementary',
#  'output',
#  'proactive',
#  'chemical',
#  'allocation',
#  'menu',
#  'acoustics',
#  'agriculture',
#  'double',
#  'assessment',
#  'broad',
#  'thing',
#  'recruiting',
#  'university',
#  'alabama',
#  'azusa',
#  'region',
#  'cleanup',
#  'typical',
#  'take',
#  'appearance',
#  'collections',
#  'collecting',
#  'emerging',
#  'basic',
#  'engagement',
#  'iteratively',
#  'tn',
#  'inputs',
#  'shooting',
#  'exempt',
#  'exist',
#  'meetings',
#  'integrator',
#  'policy',
#  'houses',
#  'serving',
#  'picking',
#  'bill',
#  'bilingual',
#  'errors',
#  'opened',
#  'playgrounds',
#  'usage',
#  'rights',
#  'material',
#  'edit',
#  'assembly',
#  'yearly',
#  'contribute',
#  'favorite',
#  'satisfactorily',
#  'eliminating',
#  'warming',
#  'co',
#  'term',
#  'purposes',
#  'gaithersburg',
#  'strengthen',
#  'every',
#  'tracking',
#  'revocation',
#  'snapshot',
#  'upbeat',
#  'op',
#  'abatement',
#  'develops',
#  'tucson',
#  'utitlities',
#  'salesforce',
#  'internationally',
#  'shape',
#  'possess',
#  'purchase',
#  'offvision',
#  'entries',
#  'illuminate',
#  'part',
#  'employer',
#  'doubled',
#  'respectful',
#  'facilitating',
#  'models',
#  'tradition',
#  'reporting',
#  'matter',
#  'governing',
#  'receive',
#  'principles',
#  'vacancies',
#  'negative',
#  'coordination',
#  'housing',
#  'retirement',
#  'central',
#  'budgeting',
#  'extraction',
#  'challenge',
#  'collaborative',
#  'securing',
#  'world',
#  'exceptional',
#  'realization',
#  'traditional',
#  'formatting',
#  'component',
#  'lines',
#  'fintek',
#  'rich',
#  'reassessing',
#  'supplying',
#  'epa',
#  'regulators',
#  'pursuant',
#  'veteran',
#  'pollens',
#  'celebrate',
#  'operate',
#  'engines',
#  'trade',
#  'preparedness',
#  'act',
#  'leader',
#  'capacity',
#  'bring',
#  'candidates',
#  'private',
#  'purchasers',
#  'epcra',
#  'exposure',
#  'disseminate',
#  'barclays',
#  'roots',
#  'chemicals',
#  'markets',
#  'ny',
#  'smartsheets',
#  'interview',
#  'displayed',
#  'systematically',
#  'retrofit',
#  'type',
#  'prioritize',
#  'delineations',
#  'china',
#  'street',
#  'door',
#  'final',
#  'submission',
#  'application',
#  'proficiency',
#  'shall',
#  'fall',
#  'leisure',
#  'subcontractors',
#  'hire',
#  'dominant',
#  'level',
#  'academic',
#  'capital',
#  'alternative',
#  'gfs',
#  'aspects',
#  'transforming',
#  'might',
#  'inventory',
#  'ways',
#  'security',
#  'gathers',
#  'modelers',
#  'accommodations',
#  'delights',
#  'enjoys',
#  'ensuring',
#  'jones',
#  'detailed',
#  'donors',
#  'aim',
#  'practitioners',
#  'vary',
#  'outputs',
#  'sessions',
#  'peer',
#  'sustainabilitycommunicate',
#  'mutually',
#  'proprietary',
#  'nearly',
#  'algebraic',
#  'jurisdictional',
#  'analysing',
#  'collaboratively',
#  'authority',
#  'powders',
#  'adapting',
#  'chains',
#  'foundational',
#  'diverse',
#  'targetx',
#  'empower',
#  'helps',
#  'club',
#  'mandated',
#  'germany',
#  'grubhub',
#  'contains',
#  'communication',
#  'complexities',
#  'covering',
#  'money',
#  'assistance',
#  'serious',
#  'advanced',
#  'modification',
#  'proposes',
#  'participate',
#  'word',
#  'ideally',
#  'active',
#  'responses',
#  'efis',
#  'overlap',
#  'appliances',
#  'digestible',
#  'amount',
#  'municipal',
#  'accessible',
#  'concerning',
#  'pertinent',
#  'proponents',
#  'environmentapplied',
#  'saas',
#  'risk',
#  'advice',
#  'crpe',
#  'oversight',
#  'traffic',
#  'fuels',
#  'coaching',
#  'liverpool',
#  'positionvalid',
#  'builds',
#  'desire',
#  'roles',
#  'hazardous',
#  'skating',
#  'stocks',
#  'good',
#  'reviewed',
#  'provider',
#  'differently',
#  'amendment',
#  'margins',
#  'ask',
#  'ambitious',
#  'protected',
#  'applies',
#  'arrange',
#  'matlab',
#  'let',
#  'supervising',
#  'bachelor',
#  'identify',
#  'covid',
#  'click',
#  'represent',
#  'system',
#  'warrants',
#  'petrochemicals',
#  'second',
#  'hvac',
#  'sponsorship',
#  'choice',
#  'placement',
#  'differentiates',
#  'website',
#  'credible',
#  'rectify',
#  'variables',
#  'open',
#  'insurancepaid',
#  'accordance',
#  'patients',
#  'botany',
#  'meeting',
#  'ehs',
#  'pacific',
#  'guiding',
#  'multiple',
#  'facilities',
#  'space',
#  'comprehensively',
#  'qgis',
#  'memphis',
#  'acuity',
#  'suite',
#  'ethnicity',
#  'eoe',
#  'match',
#  'voted',
#  'corporations',
#  'annually',
#  'burden',
#  'warehouses',
#  'pivotal',
#  'copied',
#  'everything',
#  'regular',
#  'cares',
#  'fluent',
#  'email',
#  'investigation',
#  'formats',
#  'creatively',
#  'illustrates',
#  'reach',
#  'submissions',
#  'autonomously',
#  'empowered',
#  'travelling',
#  'mandates',
#  'delegated',
#  'currently',
#  'canada',
#  'alternatives',
#  'program',
#  'trc',
#  'writes',
#  'coe',
#  'rough',
#  'housekeeping',
#  'visiting',
#  'protective',
#  'represents',
#  'trackers',
#  'locations',
#  'decarbonize',
#  'forces',
#  'instrumental',
#  'affordable',
#  'oracle',
#  'forefront',
#  'generally',
#  'alignment',
#  'analysisteam',
#  'orders',
#  'departments',
#  'get',
#  'requiredthe',
#  'startups',
#  'removed',
#  'justifying',
#  'clicking',
#  'represented',
#  'appropriately',
#  'resilience',
#  'problems',
#  'offers',
#  'gain',
#  'beyond',
#  'includes',
#  'web',
#  'addressable',
#  'unequal',
#  'user',
#  'marital',
#  'capability',
#  'places',
#  'pdf',
#  'versatile',
#  'sets',
#  'seminars',
#  'computer',
#  'debate',
#  'researcher',
#  'bridges',
#  'ferpa',
#  'early',
#  'decarbonizing',
#  'mitigate',
#  'roadmap',
#  'youtube',
#  'processes',
#  'iii',
#  'thought',
#  'punctuality',
#  'crm',
#  'scientists',
#  'demand',
#  'negotiating',
#  'atypical',
#  'student',
#  'tomorrow',
#  'competed',
#  'spore',
#  'chile',
#  'requirements',
#  'economy',
#  'oversees',
#  'commercialization',
#  'comply',
#  'problemsstriving',
#  'wastewater',
#  'scenarios',
#  'https',
#  'playing',
#  'abuse',
#  'duty',
#  'trainingat',
#  'exhaustive',
#  'mechanisms',
#  'volunteering',
#  'animal',
#  'waltham',
#  'assignmentsdesire',
#  'whether',
#  'cultural',
#  'controlsknowledge',
#  'emphasis',
#  'americans',
#  'stocked',
#  'probationary',
#  'posts',
#  'units',
#  'clearly',
#  'expenses',
#  'given',
#  'database',
#  'play',
#  'phd',
#  'avenue',
#  'investors',
#  'liaison',
#  'written',
#  'energypro',
#  'ethic',
#  'performed',
#  'gym',
#  'crimes',
#  'tetra',
#  'st',
#  'residence',
#  'charts',
#  'center',
#  'criteriasupports',
#  'compromising',
#  'partnerships',
#  'interacting',
#  'effectiveness',
#  'employed',
#  'furtherance',
#  'designed',
#  'steve',
#  'sure',
#  'manner',
#  'commensurate',
#  'processing',
#  'encroach',
#  'investigating',
#  'estate',
#  'wider',
#  'record',
#  'resilient',
#  'vp',
#  'summaries',
#  'habitat',
#  'multidisciplinary',
#  'papers',
#  'spend',
#  'systemic',
#  'helping',
#  'full',
#  'able',
#  'corporate',
#  'herein',
#  'accrual',
#  'tenant',
#  'styles',
#  'streamlined',
#  'csr',
#  'backgrounds',
#  'sick',
#  'indicators',
#  'strategist',
#  'anaylyst',
#  'steel',
#  'credit',
#  'frequently',
#  'pursuing',
#  'accounts',
#  'demonstrated',
#  'achieving',
#  'goals',
#  'asset',
#  'clients',
#  'resolve',
#  'affecting',
#  'wipe',
#  'technicians',
#  'interactive',
#  'sourcing',
#  'wetland',
#  'dataexcellent',
#  'examination',
#  'federal',
#  'coffee',
#  'transfer',
#  'relationship',
#  'funds',
#  'aea',
#  'teleworking',
#  'wellness',
#  'low',
#  'studio',
#  'reached',
#  'freedom',
#  'right',
#  'edge',
#  'jll',
#  'mistakes',
#  'emission',
#  'tanks',
#  'applied',
#  'strategic',
#  'set',
#  'everyone',
#  'stronger',
#  'opaque',
#  'ccpa',
#  'schedules',
#  'well',
#  'ihme',
#  'france',
#  'decision',
#  'professionally',
#  'websites',
#  'gaps',
#  'illnesses',
#  'matches',
#  'ambitions',
#  'architecture',
#  'outlined',
#  'change',
#  'prompted',
#  'fungal',
#  'registered',
#  'care',
#  'machinery',
#  'mapit',
#  'attribute',
#  'party',
#  'use',
#  'collection',
#  'colour',
#  'formulation',
#  'communicator',
#  'productive',
#  'advise',
#  'clearance',
#  'handle',
#  'skype',
#  'facility',
#  'disrupt',
#  'guided',
#  'mathematics',
#  'footprints',
#  'pollution',
#  'modernize',
#  'root',
#  'reservoir',
#  'electric',
#  'important',
#  'small',
#  'association',
#  'communicates',
#  'networks',
#  'brokerage',
#  'healthcare',
#  'themes',
#  'days',
#  'temporary',
#  'validation',
#  'harassment',
#  'tables',
#  'force',
#  'experienced',
#  'master',
#  'title',
#  'west',
#  'constant',
#  'embrace',
#  'lettersome',
#  'thresholds',
#  'responds',
#  'name',
#  'acceptability',
#  'instill',
#  'constructively',
#  'rapid',
#  'narrative',
#  'section',
#  'cost',
#  'bridge',
#  'guidelines',
#  'ambition',
#  'ordinarily',
#  'facilitation',
#  'ergers',
#  'admissions',
#  'difficult',
#  'seat',
#  'becc',
#  'landscapes',
#  'attitude',
#  'intimidating',
#  'spreadsheets',
#  'defects',
#  'conservation',
#  'workflows',
#  'ads',
#  'involves',
#  'boundless',
#  'artistic',
#  'grill',
#  'assignments',
#  'site',
#  'kills',
#  'additional',
#  'lieu',
#  'met',
#  'packages',
#  'tailors',
#  'cgmps',
#  'ethnic',
#  'entrepreneurialism',
#  'dow',
#  'firmness',
#  'niche',
#  'average',
#  'meticulous',
#  'mediums',
#  'summarywe',
#  'wholesome',
#  'writing',
#  'ranking',
#  'advocating',
#  'md',
#  'physician',
#  'presence',
#  'ensures',
#  'forbes',
#  'stochastic',
#  'backed',
#  'protein',
#  'filters',
#  'breeam',
#  'microscopy',
#  'generosity',
#  'clarity',
#  'appointed',
#  'complex',
#  'respectability',
#  'researching',
#  'levels',
#  'participatory',
#  'programming',
#  'customer',
#  'classification',
#  'group',
#  'absorb',
#  'dependents',
#  'robust',
#  'assure',
#  'regarding',
#  'familiar',
#  'ka',
#  'approximately',
#  'usa',
#  'assigning',
#  'proceedings',
#  'conflicting',
#  'series',
#  'particular',
#  'internet',
#  'points',
#  'responsibiliities',
#  'procurements',
#  'summarising',
#  'analytic',
#  'utilization',
#  'bigger',
#  'recruit',
#  'decisively',
#  'keyboard',
#  'amortization',
#  'founder',
#  'electronics',
#  'seattle',
#  'contributing',
#  'nondiscriminatory',
#  'sources',
#  'insight',
#  'recycling',
#  'cultivate',
#  'end',
#  'passions',
#  'consumption',
#  'excitement',
#  'identification',
#  'supplies',
#  'little',
#  'strategies',
#  'brilliant',
#  'hold',
#  'zones',
#  'galaxy',
#  'briefs',
#  'managementcoordinate',
#  'provisions',
#  'denver',
#  'oversee',
#  'lifestyle',
#  'reflecting',
#  'policymaker',
#  'greater',
#  'evidence',
#  'check',
#  ...}
